# %% [raw]
# Linear regression - Linear regression in machine learning to finding the relationship between
#                     one dependent variable and one or more independent continous variable.

# %% [markdown]
# # 1. import the necessary libraries -

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # 2. import the dataset -

# %%
df = pd.read_csv("Salary_Data.csv")

# %% [markdown]
# **Checking the null values contaning in this dataset or not.**

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %% [markdown]
# # Features of the data -

# %%
X = df.iloc[:,:-1].values
y = df.iloc[:,-1].values

# %% [markdown]
# ***There is no null values in this dataset that's why we can directly apply the train_test_split***

# %% [markdown]
# # 3. Spliting the data into training set or testing set -

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 1/2,random_state = 0)

# %% [markdown]
# # 4.Training the simple linear model on the training set -

# %%
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # 5.Visualization on the training set result -

# %% [markdown]
# # This is only for training set result -

# %% [markdown]
# # With predict -

# %%
plt.scatter(X_train,y_train,marker = "*",color = "k",s = 120)
plt.plot(X_train,regressor.predict(X_train),color = "blue")
plt.xlabel("Years of experience",fontsize = 17,color = "red")
plt.ylabel("Salary",fontsize = 17,color = "red")
plt.title("Linear Regression",fontsize = 17,color = "red")
plt.show()

# %% [markdown]
# # Without predict -

# %%
plt.scatter(X_train,y_train,marker = "*",color = "k",s = 120)
plt.plot(X,y,color = "blue")
plt.xlabel("Years of experience",fontsize = 17,color = "red")
plt.ylabel("Salary",fontsize = 17,color = "red")
plt.title("Linear Regression",fontsize = 17,color = "red")
plt.show()

# %% [markdown]
# # This is for test set result -

# %%
plt.scatter(X_test,y_test,marker = "*",color = "k",s = 120)
plt.plot(X_test,regressor.predict(X_test),color = "blue")
plt.xlabel("Years of experience",fontsize = 17,color = "red")
plt.ylabel("Salary",fontsize = 17,color = "red")
plt.title("Linear Regression",fontsize = 17,color = "red")
plt.show()

# %% [markdown]
# # let's see the difference between both of them -

# %%
y_pred = regressor.predict(X_test)

# %%
np.set_printoptions(precision = 2)
print(np.concatenate((y_pred.reshape(len(y_pred),1),y_test.reshape(len(y_test),1)),axis = 1))
# Out:
# [[ 41050.79  37731.  ]
#  [121866.4  122391.  ]
#  [ 64928.13  57081.  ]
#  [ 63091.41  63218.  ]
#  [114519.53 116969.  ]
#  [107172.66 109431.  ]
#  [115437.89 112635.  ]
#  [ 64009.77  55794.  ]
#  [ 75948.44  83088.  ]
#  [ 99825.78 101302.  ]
#  [ 53907.82  56642.  ]
#  [ 74111.72  66029.  ]
#  [ 56662.9   64445.  ]
#  [ 68601.57  61111.  ]
#  [102580.86 113812.  ]]
